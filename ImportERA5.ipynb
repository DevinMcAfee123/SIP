# %%
event = 'Plymouth'

files= [f'{event}temp.nc', f'{event}vv.nc', f'{event}u.nc', f'{event}v.nc', f'{event}rh.nc', f'{event}geo.nc',\
       f'{event}q.nc']

# %%
import cdsapi

c = cdsapi.Client()

file = files[-1]
for variable in ['specific_humidity']:

    if event== 'Albany':
        time_retrieval = ['09:00', '10:00', '11:00','12:00', '13:00', '14:00','15:00', '16:00']
        month = '02'
        day = '25'
    else:
        time_retrieval = ['14:00','15:00', '16:00', '17:00', '18:00', '19:00']
        month = '01'
        day = '29'

    c.retrieve(
        'reanalysis-era5-pressure-levels',
        {
            'product_type': 'reanalysis',
            'format': 'netcdf',
            'variable': variable,
            'pressure_level': [
                '1', '2', '3',
                '5', '7', '10',
                '20', '30', '50',
                '70', '100', '125',
                '150', '175', '200',
                '225', '250', '300',
                '350', '400', '450',
                '500', '550', '600',
                '650', '700', '750',
                '775', '800', '825',
                '850', '875', '900',
                '925', '950', '975',
                '1000',
            ],
            'year': '2022',
            'month': f'{month}',
            'day': f'{day}',
            'time': time_retrieval,
        },
        file)
# Out:
# 2022-11-28 17:54:30,863 INFO Welcome to the CDS
# 2022-11-28 17:54:30,865 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2022-11-28 17:54:31,104 INFO Request is queued
# 2022-11-28 17:54:32,279 INFO Request is running
# 2022-11-28 17:54:53,167 INFO Request is completed
# 2022-11-28 17:54:53,170 INFO Downloading https://download-0001-clone.copernicus-climate.eu/cache-compute-0001/cache/data0/adaptor.mars.internal-1669679683.351621-5357-2-8d364511-067a-4248-bd6e-41ee2faa584c.nc to Plymouthq.nc (439.6M)
# 2022-11-28 17:56:26,070 INFO Download rate 4.7M/s

# %%
import cdsapi

c = cdsapi.Client()

file_idx = 0
for variable in ['temperature', 'vertical_velocity', 'u_component_of_wind', 'v_component_of_wind', \
                'relative_humidity', 'geopotential']:
    file = files[file_idx]
    file_idx+=1

    if event== 'Albany':
        time_retrieval = ['09:00', '10:00', '11:00','12:00', '13:00', '14:00','15:00', '16:00']
        month = '02'
        day = '25'
    else:
        time_retrieval = ['14:00','15:00', '16:00', '17:00', '18:00', '19:00']
        month = '01'
        day = '29'

    c.retrieve(
        'reanalysis-era5-pressure-levels',
        {
            'product_type': 'reanalysis',
            'format': 'netcdf',
            'variable': variable,
            'pressure_level': [
                '1', '2', '3',
                '5', '7', '10',
                '20', '30', '50',
                '70', '100', '125',
                '150', '175', '200',
                '225', '250', '300',
                '350', '400', '450',
                '500', '550', '600',
                '650', '700', '750',
                '775', '800', '825',
                '850', '875', '900',
                '925', '950', '975',
                '1000',
            ],
            'year': '2022',
            'month': f'{month}',
            'day': f'{day}',
            'time': time_retrieval,
        },
        file)
# Out:
# 2022-11-23 10:52:27,436 INFO Welcome to the CDS
# 2022-11-23 10:52:27,439 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2022-11-23 10:52:27,811 INFO Request is queued
# 2022-11-23 10:52:28,981 INFO Request is running
# 2022-11-23 10:53:01,189 INFO Request is completed
# 2022-11-23 10:53:01,192 INFO Downloading https://download-0020.copernicus-climate.eu/cache-compute-0020/cache/data1/adaptor.mars.internal-1669222364.1405556-8441-3-d1726d07-ddf9-41c3-8eac-dd62232a6feb.nc to Albanytemp.nc (586.2M)
# 2022-11-23 10:59:24,902 INFO Download rate 1.5M/s
# 2022-11-23 10:59:25,932 INFO Welcome to the CDS
# 2022-11-23 10:59:25,935 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# ...
